# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
import time
from threading import Thread
import traceback

# %%
def get_proxy():
    return requests.get("http://127.0.0.1:5010/get").json()

def delete_proxy(proxy):
    requests.get("http://127.0.0.1:5010/delete/?proxy={}".format(proxy))
    
def Change_The_Time_Type(str_time):
    m, s = str_time.split(':')
    return int(m) * 60 + int(s)

# %%
get_proxy()
# Out:
# {'anonymous': '',
#  'check_count': 2,
#  'fail_count': 0,
#  'https': False,
#  'last_status': True,
#  'last_time': '2022-05-22 18:08:27',
#  'proxy': '112.6.117.135:8085',
#  'region': '',
#  'source': 'freeProxy04/freeProxy08'}

# %%
# your spider code

def play_one(video_url):
    # ....
    retry_count = 5
    proxy = get_proxy().get("proxy")
    delete_proxy(proxy)                 # 立刻删除代理池中代理，以后要优化可以改成使用队列，保证多线程安全
    
    while retry_count > 0:
        try:
            # 设置代理
            # chromeOptions = webdriver.ChromeOptions()
            # chromeOptions.add_argument(f"-proxy-server=http：//{proxy}")
            options = Options()
            options.add_argument(f"-proxy-server=http：//{proxy}")
            options.add_argument('--no-sandbox')
            
            # 我真是大开眼界，--改成-，冒号改成中文，才能用
            # 一定要注意，=两边不能有空格，不能是这样--proxy-server = http://202.20.16.82:10152
            # browser = webdriver.Chrome(r'C:\Program Files\Google\Chrome\Application/chromedriver.exe',
            #                            options=chromeOptions)
            
            driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
            
            # 使用代理访问
            # 打开视频播放页
            driver.get(video_url)
            
            time.sleep(5)
            
            # 两倍速似乎有bug，b站会认为只播放了一半，取消之
            # 两倍速
            element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
            webdriver.ActionChains(driver).move_to_element(element).click(element).perform()
            element=driver.find_element_by_xpath("//ul[@class='bilibili-player-video-btn-speed-menu']/li[4]")
            webdriver.ActionChains(driver).move_to_element(element).click(element).perform()
            
            # 获取视频时长
            #element=driver.find_element_by_xpath("//ul[@class='bilibili-player-video-btn-speed-menu']/li[1]")
            #webdriver.ActionChains(driver).move_to_element(element)
            Video_Time = driver.find_element(by=By.CSS_SELECTOR, value="span.bilibili-player-video-time-total").text
            print(Video_Time)
            Total_Second = Change_The_Time_Type(Video_Time)
            print(Total_Second)

            # 点击播放
            # element=driver.find_element_by_xpath("//button[@class='bilibili-player-iconfont bilibili-player-iconfont-start']")
            # webdriver.ActionChains(driver).move_to_element(element).click(element).perform()

            # 页面最小化
            driver.minimize_window() 

            # 看完视频
            time.sleep(Total_Second + 5) # 留出5秒余度
            
            # https://blog.csdn.net/HGGshiwo/article/details/107661135
            return
        
        except Exception as e:
            traceback.print_exc()
            retry_count -= 1
        finally:
            # 关闭页面
            driver.close()

    return None

# %%
def always_play(url):
    while True:
        play_one(url)

# %%
play_one('https://www.bilibili.com/video/BV1Bv4y1N7Gg')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# C:\Users\84220\AppData\Local\Temp/ipykernel_3416/3680066888.py:33: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
# C:\Users\84220\AppData\Local\Temp/ipykernel_3416/3680066888.py:35: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element=driver.find_element_by_xpath("//ul[@class='bilibili-player-video-btn-speed-menu']/li[4]")
# 00:46
# 46

# %%
thread = 5   # 5个线程
url = 'https://www.bilibili.com/video/BV1Bv4y1N7Gg'

thread_list = [Thread(target=always_play, args=(url,)) for _ in range(thread)]
for t in thread_list:
    t.start()
    time.sleep(12)

'''
for t in thread_list:
    t.join()
'''
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py:33: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
# C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py:35: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   element=driver.find_element_by_xpath("//ul[@class='bilibili-player-video-btn-speed-menu']/li[4]")
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# '\nfor t in thread_list:\n    t.join()\n'
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# 00:46
# 46
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 43, in play_one
#     Total_Second = Change_The_Time_Type(Video_Time)
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/86735731.py", line 8, in Change_The_Time_Type
#     m, s = str_time.split(':')
# ValueError: not enough values to unpack (expected 2, got 1)
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# 00:46
# 46
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 43, in play_one
#     Total_Second = Change_The_Time_Type(Video_Time)
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/86735731.py", line 8, in Change_The_Time_Type
#     m, s = str_time.split(':')
# ValueError: not enough values to unpack (expected 2, got 1)
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# 00:46
# 46
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
# ...
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Traceback (most recent call last):
#   File "C:\Users\84220\AppData\Local\Temp/ipykernel_9140/149499368.py", line 33, in play_one
#     element=driver.find_element_by_xpath("//button[@class='bilibili-player-video-btn-speed-name']")
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 526, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 1251, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 430, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\84220\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[@class='bilibili-player-video-btn-speed-name']"}
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008AB8F3+2406643]
# 	Ordinal0 [0x0083AF31+1945393]
# 	Ordinal0 [0x0072C748+837448]
# 	Ordinal0 [0x007592E0+1020640]
# 	Ordinal0 [0x0075957B+1021307]
# 	Ordinal0 [0x00786372+1205106]
# 	Ordinal0 [0x007742C4+1131204]
# 	Ordinal0 [0x00784682+1197698]
# 	Ordinal0 [0x00774096+1130646]
# 	Ordinal0 [0x0074E636+976438]
# 	Ordinal0 [0x0074F546+980294]
# 	GetHandleVerifier [0x00B19612+2498066]
# 	GetHandleVerifier [0x00B0C920+2445600]
# 	GetHandleVerifier [0x00944F2A+579370]
# 	GetHandleVerifier [0x00943D36+574774]
# 	Ordinal0 [0x00841C0B+1973259]
# 	Ordinal0 [0x00846688+1992328]
# 	Ordinal0 [0x00846775+1992565]
# 	Ordinal0 [0x0084F8D1+2029777]
# 	BaseThreadInitThunk [0x75C46739+25]
# 	RtlGetFullPathName_UEx [0x77AB8FEF+1215]
# 	RtlGetFullPathName_UEx [0x77AB8FBD+1165]
#
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
#
#
# ====== WebDriver manager ======
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\84220\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# 00:46
# 46
# 00:46
# 46
# 00:46
# 46
